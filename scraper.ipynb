# %% [markdown]
# # 1. Imports

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import requests

# %% [markdown]
# # 2. Functions

# %% [markdown]
# **Key Points of the Script:**
# 1. **WebDriver Setup**: It initializes a headless Chrome driver.
# 2. **Job Scraping**: The function `scrape_jobs` navigates the LinkedIn job search results, automatically scrolling to load more entries until it gathers the desired number of job postings or reaches the end.
# 3. **Data Extraction**: For each job listing, the script extracts the job title, company name, location, and salary (if available). If salary isn't listed, it notes "Not listed".
# 4. **Analysis**: Converts the scraped data into a Pandas DataFrame to facilitate straightforward data manipulation and analysis.
# 5. **Graceful Shutdown**: Ensures the WebDriver is properly closed after the scraping is complete.
#
# **Considerations**:
# - **Dynamic Content**: Selenium waits are used to ensure that the page loads completely before attempting to find elements.
# - **Error Handling**: Basic error handling includes skipping over job listings that don't have all the expected fields.
# - **Headless Operation**: The script runs Chrome in headless mode for better performance, especially useful when running on servers or automated environments.
#
# This script is configured for educational purposes and assumes ethical use, with proper respect for LinkedIn's terms of service. For practical use, you'd need to ensure compliance with LinkedIn's data use policies.

# %%
def setup_driver():
    # Setup Chrome WebDriver
    chrome_options = webdriver.ChromeOptions()
    #options.add_argument('--headless')  # Runs Chrome in headless mode.
    #options.add_argument('--no-sandbox')
    #options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=chrome_options)
    return driver

# %%
def scrape_jobs(driver, url, num_results=5):
    print("Navigating to the page...")
    driver.get(url)
    time.sleep(2)  # Allow some time for the page to load
    results = []
    count = 0
    last_height = driver.execute_script("return document.body.scrollHeight")

    print(f"Starting the scrape for {num_results} job postings...")
    while count < num_results:
        job_cards = driver.find_elements(
            By.CLASS_NAME, 'base-search-card__info')
        print(f"Found {len(job_cards)} job cards on the page:")
        for card in job_cards[count:]:
            job_title = card.find_element(By.CLASS_NAME, 'base-search-card__title').text if card.find_elements(
                By.CLASS_NAME, 'base-search-card__title') else "Not listed"
            company_name = card.find_element(By.CLASS_NAME, 'base-search-card__subtitle').text if card.find_elements(
                By.CLASS_NAME, 'base-search-card__subtitle') else "Not listed"
            location = card.find_element(By.CLASS_NAME, 'job-search-card__location').text if card.find_elements(
                By.CLASS_NAME, 'job-search-card__location') else "Not listed"
            # Extract the datetime attribute from the <time> element
            post_date = card.find_element(By.CLASS_NAME, 'job-search-card__listdate').get_attribute(
                'datetime') if card.find_elements(By.CLASS_NAME, 'job-search-card__listdate') else "Not listed"

            results.append({
                'Job Title': job_title,
                'Company Name': company_name,
                'Location': location,
                # 'Salary': salary,
                'Posted Date': post_date  # Add the extracted date to the results dictionary
            })
            print(
                f"Scraped {count + 1}/{num_results}: {job_title} at {company_name}")
            count += 1

        # Scroll down to bottom
        driver.execute_script(
            "window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            print("Reached the end of the page or no more job cards to load.")
            break
        last_height = new_height

    return results

# %%
def analyze_data(data):
    # This function converts the list of dictionaries (data) into a pandas DataFrame
    # for easier data manipulation and subsequent analysis.
    df = pd.DataFrame(data)

    # The `describe()` method provides a summary of statistics pertaining to the DataFrame columns,
    # including mean, standard deviation, min, and max values, which can be useful for understanding
    # the distribution of numerical data in the dataset.
    df.describe()

    return df
    

def main():
    # Initialize the Chrome WebDriver using a helper function that sets up the driver with necessary options.
    driver = setup_driver()

    # URL setup for the LinkedIn job search based on specific keywords and location.
    url = 'https://www.linkedin.com/jobs/search/?keywords=sales%20development%20representative&location=United%20States'

    try:
        # Scrape job data from LinkedIn using the scrape_jobs function, aiming to collect data on 1000 job postings.
        job_data = scrape_jobs(driver, url, 40)

        # Analyze the scraped job data using the analyze_data function and print the statistical summary.
        DF = analyze_data(job_data)
        print(DF)

    finally:
        # Ensure the driver is properly quit after scraping to free resources and avoid any leftover processes.
        driver.quit()
        return DF

# %% [markdown]
# # Running Scraper

# %%
DF = main()
# Out:
# Navigating to the page...
# Starting the scrape for 40 job postings...
# Found 60 job cards on the page:
# Scraped 1/40: Sales Development Representative at Carta
# Scraped 2/40: Sales Development Representative at WorkWave
# Scraped 3/40: Sales Development Representative at PEC - Pacific Energy Concepts
# Scraped 4/40: Sales Development Representative at Bright Power, Inc.
# Scraped 5/40: Sales Development Representative at Rentable
# Scraped 6/40: Sales Development Representative at The Predictive Index
# Scraped 7/40: Sales Development Representative (New Grad) at PermitFlow
# Scraped 8/40: Sales Development Representative at Modern Health
# Scraped 9/40: Sales Development Representative at Pentera
# Scraped 10/40: Sales Development Representative at Certus Recruitment Group
# Scraped 11/40: Sales Development Representative at Compass
# Scraped 12/40: Sales Development Representative, East at Okta
# Scraped 13/40: Sales Development Representative at Kargo
# Scraped 14/40: Inside Sales Representative at Beyond Finance
# Scraped 15/40: Sales Development Representative at Axcient
# Scraped 16/40: Sales Development Representative at Workera
# Scraped 17/40: Sales Development Representative at Flowhub
# Scraped 18/40: Sales Development Representative (SDR) at PermitFlow
# Scraped 19/40: Sales Development Representative at Shopmonkey
# Scraped 20/40: Sales Development Representative at Accomplishr
# Scraped 21/40: Sales Development Representative at Nava Benefits
# Scraped 22/40: Sales Development Representative at BigID
# Scraped 23/40: Inside Sales Representative at Crawford Thomas Recruiting
# Scraped 24/40: Sales Development Representative at Oracle
# Scraped 25/40: Sales Development Representative at Maze
# Scraped 26/40: Sales Development Representative at Oppizi
# Scraped 27/40: Sales Development Representative at Drawbridge
# Scraped 28/40: Sales Development Representative at OneTrust
# Scraped 29/40: Sales Development Representative at TrueVault
# Scraped 30/40: Inside Sales Representative at Boston Celtics
# Scraped 31/40: Sales Development Representative at Ramp
# Scraped 32/40: Inside Sales Representative at Bisnow
# Scraped 33/40: Sales Development Representative at Insight Global
# Scraped 34/40: Sales Development Representative at Stealth
# Scraped 35/40: Inbound Sales Development Representative - AMER at Notion
# Scraped 36/40: Sales Development Representative at Honest Search
# Scraped 37/40: Sales Development Representative at Pathlock
# Scraped 38/40: Sales Development Representative at ACTIVE Network
# Scraped 39/40: Sales Development Representative (HYBRID) at InBody USA
# Scraped 40/40: Sales Development Representative at City Innovate Inc
# Scraped 41/40: Sales Development Representative at SigTech
# Scraped 42/40: Sales Development Representative (SDR) at Paradigm Life
# Scraped 43/40: Sales Development Representative - USA West at SWTCH
# Scraped 44/40: Sales Development Representative at Documo
# Scraped 45/40: Sales Development Representative at FMX
# Scraped 46/40: Sales Development Representative at Formic
# 59  2024-04-16

# %%
DF
# Out:
#                                           Job Title  \
# 0                  Sales Development Representative
# 1                  Sales Development Representative
# 2                  Sales Development Representative
# 3                  Sales Development Representative
# 4                  Sales Development Representative
# 5                  Sales Development Representative
# 6       Sales Development Representative (New Grad)
# 7                  Sales Development Representative
# 8                  Sales Development Representative
# 9                  Sales Development Representative
# 10                 Sales Development Representative
# 11           Sales Development Representative, East
# 12                 Sales Development Representative
# 13                      Inside Sales Representative
# 14                 Sales Development Representative
# 15                 Sales Development Representative
# 16                 Sales Development Representative
# 17           Sales Development Representative (SDR)
# 18                 Sales Development Representative
# 19                 Sales Development Representative
# 20                 Sales Development Representative
# 21                 Sales Development Representative
# 22                      Inside Sales Representative
# 23                 Sales Development Representative
# 24                 Sales Development Representative
# 25                 Sales Development Representative
# 26                 Sales Development Representative
# 27                 Sales Development Representative
# 28                 Sales Development Representative
# 29                      Inside Sales Representative
# 30                 Sales Development Representative
# 31                      Inside Sales Representative
# 32                 Sales Development Representative
# 33                 Sales Development Representative
# 34  Inbound Sales Development Representative - AMER
# 35                 Sales Development Representative
# 36                 Sales Development Representative
# 37                 Sales Development Representative
# 38        Sales Development Representative (HYBRID)
# 39                 Sales Development Representative
# 40                 Sales Development Representative
# 41           Sales Development Representative (SDR)
# 42      Sales Development Representative - USA West
# 43                 Sales Development Representative
# 44                 Sales Development Representative
# 45                 Sales Development Representative
# 46  Sales Development Representative- Dynamic Yield
# 47                 Sales Development Representative
# 48                 Sales Development Representative
# 49            Sales Development Representative - AI
# 50                 Sales Development Representative
# 51                 Sales Development Representative
# 52                 Sales Development Representative
# 53                 Sales Development Representative
# 54                 Sales Development Representative
# 55                 Sales Development Representative
# 56                 Sales Development Representative
# 57                 Sales Development Representative
# 58                 Sales Development Representative
# 59                      Inside Sales Representative
#
#                      Company Name                          Location  \
# 0                           Carta                 San Francisco, CA
# 1                        WorkWave                 Metro Detroit, MI
# 2   PEC - Pacific Energy Concepts                     Vancouver, WA
# 3              Bright Power, Inc.                      New York, NY
# 4                        Rentable                       Madison, WI
# 5            The Predictive Index                      Westwood, MA
# 6                      PermitFlow                      New York, NY
# 7                   Modern Health                       Atlanta, GA
# 8                         Pentera                    Greater Boston
# 9        Certus Recruitment Group       Dallas-Fort Worth Metroplex
# 10                        Compass                      New York, NY
# 11                           Okta                    Washington, DC
# 12                          Kargo                 San Francisco, CA
# 13                 Beyond Finance                       Atlanta, GA
# 14                        Axcient                        Denver, CO
# 15                        Workera                     United States
# 16                        Flowhub                     United States
# 17                     PermitFlow                      New York, NY
# 18                     Shopmonkey               Utah, United States
# 19                    Accomplishr                     United States
# 20                  Nava Benefits                     San Diego, CA
# 21                          BigID                     United States
# 22     Crawford Thomas Recruiting                    Centennial, CO
# 23                         Oracle   Austin, Texas Metropolitan Area
# 24                           Maze                     United States
# 25                         Oppizi           New York, United States
# 26                     Drawbridge                      New York, NY
# 27                       OneTrust                       Atlanta, GA
# 28                      TrueVault   New York City Metropolitan Area
# 29                 Boston Celtics                        Boston, MA
# 30                           Ramp           New York, United States
# 31                         Bisnow                       Chicago, IL
# 14                 Sales Development Representative  Bright Power, Inc.
# 15                 Sales Development Representative            Workable
# 16                 Sales Development Representative            Monetate
# 17                 Sales Development Representative           TrueVault
# 18                 Sales Development Representative                Silo
# 19           Sales Development Representative (SDR)           Blue Bite
# 20                 Sales Development Representative            Rentable
# 21                 Sales Development Representative              Documo
# 22                 Sales Development Representative           Primer.ai
# 23                 Sales Development Representative               Carta
# 24                 Sales Development Representative              Oracle
#
#                            Location      Salary
# 0                      New York, NY  Not listed
# 1            San Francisco Bay Area  Not listed
# 2                        Boston, MA  Not listed
# 3                     United States  Not listed
# 4                   Los Angeles, CA  Not listed
# 5                     United States  Not listed
# 6                     United States  Not listed
# 7                Salt Lake City, UT  Not listed
# 8                 San Francisco, CA  Not listed
# 9                      New York, NY  Not listed
# 10                     New York, NY  Not listed
# 11                       Boston, MA  Not listed
# 12                       Irvine, CA  Not listed
# 13                    United States  Not listed
# 14                     New York, NY  Not listed
# 15                       Boston, MA  Not listed
# 16                    United States  Not listed
# 17  New York City Metropolitan Area  Not listed
# 18                     New York, NY  Not listed
# 19                     New York, NY  Not listed
# 20                      Madison, WI  Not listed
# 21                    United States  Not listed
# 22                   Washington, DC  Not listed
# 23                San Francisco, CA  Not listed
# 24  Austin, Texas Metropolitan Area  Not listed

# %%
API_TOKEN = "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"

# %%
with open('sample_job_description.txt', 'r') as file:
    job_description = file.read()

with open('sample_job_description_2.txt', 'r') as file:
    job_description_2 = file.read()

with open('sample_job_description_3.txt', 'r') as file:
    job_description_3 = file.read()

with open('sample_job_description_4.txt', 'r') as file:
    job_description_4 = file.read()

# %%
prompt = '''
How much is this job paying? What is the salary? (ONLY print that number; do not print anything else!!!)
'''

# %%
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/deepset/roberta-base-squad2"


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query(
    {
        "inputs": {
            "question": prompt,
            "context": job_description_2,
        }
    }
)

# %%
data
# Out:
# {'score': 0.08668936043977737, 'start': 3333, 'end': 3340, 'answer': '$64,500'}

# %% [markdown]
# ## Testing Hugging Face API

# %%
import requests

# %%
API_TOKEN = "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"

# %%
API_URL = "https://api-inference.huggingface.co/models/gpt2"
headers = {"Authorization": f"Bearer {API_TOKEN}"}


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query("Can you please let us know more details about your ")

# %%
data
# Out:
# [{'generated_text': 'Can you please let us know more details about your iphone, so it can get through to you?\n\nThank you for your time on our podcast.'}]

# %%
prompt = '''
How much is this job paying? What is the salary? (ONLY print that number; do not print anything else!!!)
'''

# %% [markdown]
# **Now Testing with Google Gemini 7b**

# %%
with open('sample_job_description.txt', 'r') as file:
    job_description = file.read()

with open('sample_job_description_2.txt', 'r') as file:
    job_description_2 = file.read()

with open('sample_job_description_3.txt', 'r') as file:
    job_description_3 = file.read()

with open('sample_job_description_4.txt', 'r') as file:
    job_description_4 = file.read()

# %%
API_URL = "https://api-inference.huggingface.co/models/gpt2"
headers = {"Authorization": f"Bearer {API_TOKEN}"}


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query("Can you please let us know more details about your ")

# %%
data
# Out:
# [{'generated_text': 'Can you please let us know more details about your iphone, so it can get through to you?\n\nThank you for your time on our podcast.'}]

# %%
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/deepset/roberta-base-squad2"


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query(
    {
        "inputs": {
            "question": "What's my name?",
            "context": "My name is Clara and I live in Berkeley.",
        }
    }
)

# %%
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/deepset/roberta-base-squad2"


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query(
    {
        "inputs": {
            "question": prompt,
            "context": job_description_4,
        }
    }
)

# %%
data
# Out:
# {'score': 0.35506680607795715,
#  'start': 1033,
#  'end': 1065,
#  'answer': 'Sales Development Representative'}

# %%
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/deepset/roberta-base-squad2"


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query(
    {
        "inputs": {
            "question": "What's my name?",
            "context": "My name is Clara and I live in Berkeley.",
        }
    }
)

# %%
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/google/gemma-1.1-7b-it"


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


data = query(
    {

        "chat" : {"role": "user", 
                 "content" : "<bos><start_of_turn>user Write a hello world program<end_of_turn> <start_of_turn>model" }
    }
)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\chris\anaconda3\envs\linkedin-scraping\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\chris\anaconda3\envs\linkedin-scraping\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\chris\anaconda3\envs\linkedin-scraping\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\chris\anaconda3\envs\linkedin-scraping\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[91], line 10
#       6     response = requests.post(API_URL, headers=headers, json=payload)
#       7     return response.json()
# ---> 10 data = query(
#      11     {
#      12
#      13         "chat" : {"role": "user",
#      14                  "content" : "<bos><start_of_turn>user Write a hello world program<end_of_turn> <start_of_turn>model" }
#      15     }
#      16 )
#
# Cell In[91], line 7, in query(payload)
#       5 def query(payload):
#       6     response = requests.post(API_URL, headers=headers, json=payload)
# ----> 7     return response.json()
#
# File c:\Users\chris\anaconda3\envs\linkedin-scraping\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests

headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/google/gemma-1.1-7b-it"


def query(payload):
    try:
        response = requests.post(API_URL, headers=headers, json=payload)
        if response.status_code != 200:
            print(f"Error: API returned status code {response.status_code}")
            return None  # Or handle the error differently

        return response.json()
    except JSONDecodeError as e:
        print("Error decoding JSON response:", e)
        return None  # Or handle the error differently


data = query(
    {
        "chat": {
            "question": "What's my name?",
            "context": "My name is Clara and I live in Berkeley.",
        }
    }
)

print(data)
# Out:
# Error: API returned status code 422
# None
